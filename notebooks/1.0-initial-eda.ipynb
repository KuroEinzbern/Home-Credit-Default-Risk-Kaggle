# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
from scipy.stats import trim_mean
import math
from pandas.api.types import ( is_numeric_dtype, is_categorical_dtype, is_object_dtype, is_datetime64_any_dtype )

import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from visualization.initial_eda import eda_per_table_printing_results
application_train_df = pd.read_csv("../data/application_train.csv")

with open("../metadata/schema.json", "r") as f:
    schema = json.load(f)

# %%
#Run EDA on previous application
previous_application_df = pd.read_csv("../data/previous_application.csv")
application_train_df.head()

previous_application_with_target_df = pd.merge(previous_application_df, application_train_df[['SK_ID_CURR', 'TARGET']], on='SK_ID_CURR', how='inner')
eda_per_table_printing_results(previous_application_with_target_df, schema, "previous_application",False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 6
#       3 application_train_df.head()
#       5 previous_application_with_target_df = pd.merge(previous_application_df, application_train_df[['SK_ID_CURR', 'TARGET']], on='SK_ID_CURR', how='inner')
# ----> 6 eda_per_table_printing_results(previous_application_with_target_df, schema, "previous_application",False)
#
# File c:\Users\kuroc\OneDrive\Escritorio\default risk\visualization\initial_eda.py:25, in eda_per_table_printing_results(df, schema, table_name, target_aware)
#      24 def eda_per_table_printing_results(df: pd.DataFrame,schema: dict, table_name: str, target_aware: bool):
# ---> 25     results=eda_per_table(df,schema,table_name,target_aware)
#      26     for key,values in results.items() :
#      27         print("--------------------------------------")
#
# File c:\Users\kuroc\OneDrive\Escritorio\default risk\visualization\initial_eda.py:42, in eda_per_table(df, schema, table_name, target_aware)
#      40 results={}
#      41 for col in df.columns:
# ---> 42     dict_of_dataframes,column_name= eda_per_column(df,schema,table_name,col,target_aware)
#      43     results[column_name]=dict_of_dataframes
#      44 return results
#
# File c:\Users\kuroc\OneDrive\Escritorio\default risk\visualization\initial_eda.py:49, in eda_per_column(df, schema, table_name, column_name, target_aware)
#      47 def eda_per_column(df: pd.DataFrame,schema: dict,table_name,column_name, target_aware: bool):
#      48     dict_of_dataframes={}
# ---> 49     if(is_categorical(schema,table_name,column_name)):
#      50         dict_of_dataframes= basic_eda_per_column_categorical(df,column_name, target_aware)
#      51     else:
#
# File c:\Users\kuroc\OneDrive\Escritorio\default risk\visualization\initial_eda.py:59, in is_categorical(schema, table_name, column_name)
#      58 def is_categorical(schema: dict,table_name,column_name):
# ---> 59     type=schema[table_name][column_name]["type"]
#      60     return type == "categorical"
#
# KeyError: 'TARGET'
